# %%
#load packages needed
import os
import matplotlib.pyplot as plt
from scipy.io import loadmat

#go to working directory
os.chdir('/Users/amrithah/Desktop/CalhounLab/Dissertation/Projects/Chapter7_Paper_6_Diss_Clinical_Outcomes/ICA_Results/Depression_ICA_Analyses_Clinical_Outcomes')
data = loadmat('Clinical_Outcomes_Workspace.mat') #Load matlab workspace for importing variables 

# See what variables are inside
print(data.keys())
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/scipy/io/matlab/_mio.py:235: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Considerscipy.io.matlab.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)
# dict_keys(['__header__', '__version__', '__globals__', 'Adjustment_Disorder', 'Alcohol_Related_Disorder', 'Amnestic_disorders', 'Amphetamine_Related_Disorder', 'Anorexia_Nervosa', 'Antisocial_Personality_Disorder', 'Anxiety_Disorder', 'Aspergers', 'Attention_Deficit_Disruptive_Behavior', 'Attention_Deficit_hyperactivity', 'Autism', 'Autonomic_HotCold_Flashes', 'Avoidant_Personality_Disorder', 'BSC_100_Having_dark_thoughts_ones_that_may_involve_suicidal_or_', 'BSC_101_Experiencing_periods_of_forgetfulness_or_memory_problem', 'BSC_10_Having_poor_planning_skills', 'BSC_11_Lacking_clear_goals_or_forward_thinking', 'BSC_12_Having_difficulty_expressing_feelings', 'BSC_13_Having_difficulty_expressing_empathy_for_others', 'BSC_14_Experiencing_excessive_daydreaming', 'BSC_15_Feeling_bored', 'BSC_16_Feeling_apathetic_or_unmotivated', 'BSC_17_Feeling_tired_sluggish_or_slow_moving', 'BSC_18_Feeling_spacey_or_in_a_fog', 'BSC_19_Feeling_fidgety_restless_or_trouble_sitting_still', 'BSC_1_Failing_to_give_close_attention_to_details_or_making_care', 'BSC_20_Having_difficulty_remaining_seated_in_situations_where_r', 'BSC_21_Running_about_or_climbing_excessively_in_situations_in_w', 'BSC_22_Having_difficulty_playing_quietly', 'BSC_23_Being_always_on_the_go_or_acting_as_if_driven_by_a_motor', 'BSC_24_Talking_excessively', 'BSC_25_Blurting_out_answers_before_questions_have_been_complete', 'BSC_26_Having_difficulty_waiting', 'BSC_27_Interrupting_or_intruding_on_others_butting_into_convers', 'BSC_28_Behaving_impulsively_saying_or_doing_things_without_thin', 'BSC_29_Worrying_excessively_or_senselessly', 'BSC_2_Having_trouble_sustaining_attention_in_routine_situations', 'BSC_30_Getting_upset_when_things_do_not_go_your_way', 'BSC_31_Getting_upset_when_things_are_out_of_place', 'BSC_32_Tending_to_be_oppositional_or_argumentative', 'BSC_33_Tending_to_have_repetitive_negative_thoughts', 'BSC_34_Tending_toward_compulsive_behaviors_things_you_feel_you_', 'BSC_35_Intensely_disliking_change', 'BSC_36_Tending_to_hold_grudges', 'BSC_37_Having_trouble_shifting_attention_from_subject_to_subjec', 'BSC_38_Having_trouble_shifting_behavior_from_task_to_task', 'BSC_39_Having_difficulties_seeing_options_in_situations', 'BSC_3_Having_trouble_listening', 'BSC_40_Tending_to_hold_on_to_own_opinion_and_not_listen_to_othe', 'BSC_41_Tending_to_get_locked_into_a_course_of_action_whether_or', 'BSC_42_Needing_to_have_things_done_a_certain_way_or_else_becomi', 'BSC_43_Others_complaining_that_you_worry_too_much', 'BSC_44_Tending_to_say_no_without_first_thinking_about_the_quest', 'BSC_45_Tending_to_predict_fear', 'BSC_46_Experiencing_frequent_feelings_of_sadness', 'BSC_47_Having_feelings_of_moodiness', 'BSC_48_Having_feelings_of_negativity', 'BSC_49_Having_low_energy', 'BSC_4_Failing_to_finish_things', 'BSC_50_Being_irritable', 'BSC_51_Having_a_decreased_interest_in_other_people', 'BSC_52_Having_a_decreased_interest_in_things_that_are_usually_f', 'BSC_53_Having_feelings_of_hopelessness_about_the_future', 'BSC_54_Having_feelings_of_helplessness_or_powerlessness', 'BSC_55_Feeling_dissatisfied_or_bored', 'BSC_56_Feeling_excessive_guilt', 'BSC_57_Having_suicidal_feelings', 'BSC_58_Having_crying_spells', 'BSC_59_Having_lowered_interest_in_things_that_are_usually_consi', 'BSC_5_Having_poor_organization_for_time_or_space_such_as_a_back', 'BSC_60_Experiencing_sleep_changes_too_much_or_too_little', 'BSC_61_Experiencing_appetite_changes_too_much_or_too_little', 'BSC_62_Having_chronic_low_selfesteem', 'BSC_63_Having_a_negative_sensitivity_to_smells_odors', 'BSC_64_Frequently_feeling_nervous_or_anxious', 'BSC_65_Experiencing_panic_attacks', 'BSC_66_Symptoms_of_heightened_muscle_tension_such_as_headaches_', 'BSC_67_Experiencing_periods_of_a_pounding_heart_a_rapid_heart_r', 'BSC_68_Experiencing_periods_of_troubled_breathing_or_feeling_sm', 'BSC_69_Experiencing_periods_of_dizziness_faintness_or_feeling_u', 'BSC_6_Avoiding_disliking_or_being_reluctant_to_engage_in_tasks_', 'BSC_70_Feeling_nausea_or ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns

#extract variables
BSC_78_Having_low_motivation = data['BSC_78_Having_low_motivation'].flatten()
BSC_87_Being_sensitive_to_criticism = data['BSC_87_Being_sensitive_to_criticism'].flatten()
BSC_12_Having_difficulty_expressing_feelings = data['BSC_12_Having_difficulty_expressing_feelings'].flatten()
BSC_45_Tending_to_predict_fear = data['BSC_45_Tending_to_predict_fear'].flatten()
BSC_70_Feeling_nausea_or_having_an_upset_stomach = data['BSC_70_Feeling_nausea_or_having_an_upset_stomach'].flatten()

# %%
# ---------------------------------------------------------
# Combine variables into a DataFrame
# ---------------------------------------------------------
df = pd.DataFrame({
    'BSC-78': BSC_78_Having_low_motivation.flatten(),
    'BSC-87': BSC_87_Being_sensitive_to_criticism.flatten(),
    'BSC-12': BSC_12_Having_difficulty_expressing_feelings.flatten(),
    'BSC-45': BSC_45_Tending_to_predict_fear.flatten(),
    'BSC-70': BSC_70_Feeling_nausea_or_having_an_upset_stomach.flatten()
})

# ---------------------------------------------------------
# Compute correlation matrix
# ---------------------------------------------------------
R = df.corr()

# ---------------------------------------------------------
# Plot heatmap
# ---------------------------------------------------------
plt.figure(figsize=(7, 6))
sns.heatmap(R, annot=True, cmap='coolwarm', vmin=-1, vmax=1, square=True)

plt.title('Correlation Heatmap Across BSC Variables')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
